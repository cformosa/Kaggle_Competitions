# %% [markdown]
# https://www.kaggle.com/c/movie-review-sentiment-analysis-kernels-only/kernels

# %%
import pandas as pd
import numpy as np
pd.set_option('max_colwidth',400)
train = pd.read_csv("train.tsv", sep="\t")
test = pd.read_csv("test.tsv", sep="\t")
train.head()
# Out:
#    PhraseId  SentenceId  \
# 0         1           1
# 1         2           1
# 2         3           1
# 3         4           1
# 4         5           1
#
#                                                                                                                                                                                          Phrase  \
# 0  A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .
# 1                                                                                                                 A series of escapades demonstrating the adage that what is good for the goose
# 2                                                                                                                                                                                      A series
# 3                                                                                                                                                                                             A
# 4                                                                                                                                                                                        series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %% [markdown]
# 0 - negative <br>
# 1 - somewhat neutral <br>
# 2 - neutral <br>
# 3 - somewhat positive <br>
# 4 - positive <br>
# Each phrase has a phrase ID. Each sentence has a sentenceID

# %%
print(len(train.PhraseId.unique()))
print(len(train.SentenceId.unique()))
# Out:
# 156060
# 8529

# %%
from nltk.tokenize import TweetTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer

#designed to be a more adaptable tokenizer for things like tweets and writing

# %%
tokenizer = TweetTokenizer()
vectorizer = TfidfVectorizer(ngram_range=(1, 2), tokenizer=tokenizer.tokenize)
full_text = list(train['Phrase'].values) + list(test['Phrase'].values)

#done a bit of reading on this and it seems sometimes this is achieving better results in the field.
#best advice is to try both to be honest
vectorizer.fit(full_text)
train_vectorized = vectorizer.transform(train['Phrase'])
test_vectorized = vectorizer.transform(test['Phrase'])

# %%
y = train['Sentiment']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
logreg = LogisticRegression()
ovr = OneVsRestClassifier(logreg)
ovr.fit(train_vectorized, y)
# Out:
# C:\Users\290002494\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# OneVsRestClassifier(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False),
#           n_jobs=None)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(ovr, train_vectorized, y, scoring='accuracy', n_jobs=-1, cv=3)
np.mean(scores)
# Out:
# 0.5655324688463249

# %% [markdown]
# Now to deep learning

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, Conv1D, GRU, BatchNormalization
from keras.layers import Bidirectional, GlobalMaxPool1D, MaxPooling1D, Add, Flatten
from keras.layers import GlobalAveragePooling1D, GlobalMaxPooling1D, concatenate, SpatialDropout1D
from keras.models import Model, load_model
from keras import initializers, regularizers, constraints, optimizers, layers, callbacks
from keras import backend as K
from keras.engine import InputSpec, Layer
from keras.optimizers import Adam

from keras.callbacks import ModelCheckpoint, TensorBoard, Callback, EarlyStopping
tokenizer = Tokenizer(lower = True)
tokenizer.fit_on_texts(full_text)

# %%
#replaces words with numeric indices
train_tokenized = tokenizer.texts_to_sequences(train['Phrase'])
test_tokenized = tokenizer.texts_to_sequences(test['Phrase'])

# %%
#need to pad them all to be the same length
max_len = 50
X_train = pad_sequences(train_tokenized, maxlen = max_len)
X_test = pad_sequences(test_tokenized, maxlen = max_len)

# %%
embedding_path = "crawl-300d-2M.vec"

# %%
embed_size = 300
max_features = 30000

# %%
#extract the word and the embedding vectors for each row in the file
embeddings_index = {}
f = open(embedding_path, encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 2000000 word vectors.

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'of': 3,
#  'and': 4,
#  'to': 5,
#  "'s": 6,
#  'in': 7,
#  'is': 8,
#  'that': 9,
#  'it': 10,
#  'as': 11,
#  'with': 12,
#  'for': 13,
#  'its': 14,
#  'film': 15,
#  'an': 16,
#  'movie': 17,
#  'this': 18,
#  'but': 19,
#  'be': 20,
#  'on': 21,
#  'you': 22,
#  'by': 23,
#  "n't": 24,
#  'more': 25,
#  'his': 26,
#  'not': 27,
#  'one': 28,
#  'than': 29,
#  'about': 30,
#  'at': 31,
#  'from': 32,
#  'or': 33,
#  'all': 34,
#  'like': 35,
#  'are': 36,
#  'have': 37,
#  'has': 38,
#  'so': 39,
#  "'": 40,
#  'out': 41,
#  'story': 42,
#  'who': 43,
#  'rrb': 44,
#  'up': 45,
#  'too': 46,
#  'good': 47,
#  'most': 48,
#  'into': 49,
#  'lrb': 50,
#  'time': 51,
#  'much': 52,
#  'what': 53,
#  'if': 54,
#  'characters': 55,
#  'no': 56,
#  'comedy': 57,
#  'their': 58,
#  'just': 59,
#  'i': 60,
#  'some': 61,
#  'can': 62,
#  'even': 63,
#  'life': 64,
#  'your': 65,
#  'little': 66,
#  'does': 67,
#  "''": 68,
#  'way': 69,
#  'well': 70,
#  'will': 71,
#  'make': 72,
#  'been': 73,
#  'funny': 74,
#  'only': 75,
#  'very': 76,
#  'he': 77,
#  'do': 78,
#  'director': 79,
#  'any': 80,
#  'enough': 81,
#  'us': 82,
#  'her': 83,
#  'bad': 84,
#  'there': 85,
#  'new': 86,
#  'love': 87,
#  'movies': 88,
#  'which': 89,
#  'they': 90,
#  'was': 91,
#  'work': 92,
#  'two': 93,
#  'own': 94,
#  'them': 95,
#  'best': 96,
#  'when': 97,
#  'action': 98,
#  'old': 99,
#  'something': 100,
#  'made': 101,
#  'we': 102,
#  'through': 103,
#  'other': 104,
#  'people': 105,
#  'never': 106,
#  'off': 107,
#  'makes': 108,
#  'would': 109,
#  'world': 110,
#  'see': 111,
#  'many': 112,
#  'character': 113,
#  'films': 114,
#  'self': 115,
#  'could': 116,
#  'how': 117,
#  'long': 118,
#  'over': 119,
#  'big': 120,
#  'may': 121,
#  'plot': 122,
#  'get': 123,
#  'first': 124,
#  'look': 125,
#  'audience': 126,
#  'being': 127,
#  'those': 128,
#  'every': 129,
#  'performances': 130,
#  'drama': 131,
#  'better': 132,
#  'great': 133,
#  'real': 134,
#  'really': 135,
#  'humor': 136,
#  'fun': 137,
#  'sense': 138,
#  "'re": 139,
#  'screen': 140,
#  'should': 141,
#  'man': 142,
#  'another': 143,
#  'year': 144,
#  'few': 145,
#  'feel': 146,
#  'still': 147,
#  'without': 148,
#  'both': 149,
#  'minutes': 150,
#  'ever': 151,
#  'hollywood': 152,
#  'cast': 153,
#  'american': 154,
#  'such': 155,
#  'down': 156,
#  'while': 157,
#  'kind': 158,
#  'human': 159,
#  'less': 160,
#  'nothing': 161,
#  'heart': 162,
#  'between': 163,
#  'far': 164,
#  'might': 165,
#  'full': 166,
#  'interesting': 167,
#  'hard': 168,
#  'performance': 169,
#  'family': 170,
#  'script': 171,
#  'seen': 172,
#  'our': 173,
#  'because': 174,
#  'rather': 175,
#  'thriller': 176,
#  'often': 177,
#  'picture': 178,
#  'right': 179,
#  'my': 180,
#  'same': 181,
#  'acting': 182,
#  'had': 183,
#  'these': 184,
#  'were': 185,
#  'original': 186,
#  'also': 187,
#  'go': 188,
#  'tale': 189,
#  'moments': 190,
#  'things': 191,
#  'quite': 192,
#  'back': 193,
#  'emotional': 194,
#  'almost': 195,
#  'take': 196,
#  'itself': 197,
#  'end': 198,
#  'young': 199,
#  'before': 200,
#  'thing': 201,
#  'here': 202,
#  'after': 203,
#  'going': 204,
#  'music': 205,
#  'times': 206,
#  'watching': 207,
#  'entertaining': 208,
#  'scenes': 209,
#  'dialogue': 210,
#  "'ve": 211,
#  'star': 212,
#  'romantic': 213,
#  'cinema': 214,
#  'ca': 215,
#  'actors': 216,
#  'find': 217,
#  'watch': 218,
#  'material': 219,
#  'where': 220,
#  'come': 221,
#  'lot': 222,
#  'war': 223,
#  'kids': 224,
#  'documentary': 225,
#  'half': 226,
#  'style': 227,
#  'video': 228,
#  'high': 229,
#  'years': 230,
#  'seems': 231,
#  'me': 232,
#  'yet': 233,
#  "'ll": 234,
#  'last': 235,
#  'though': 236,
#  'feels': 237,
#  'point': 238,
#  'special': 239,
#  'show': 240,
#  'know': 241,
#  'give': 242,
#  'history': 243,
#  'compelling': 244,
#  'takes': 245,
#  'subject': 246,
#  'him': 247,
#  'worth': 248,
#  'anything': 249,
#  'comes': 250,
#  'art': 251,
#  'entertainment': 252,
#  'making': 253,
#  'gets': 254,
#  'did': 255,
#  'least': 256,
#  'women': 257,
#  'say': 258,
#  'three': 259,
#  'keep': 260,
#  'around': 261,
#  'cinematic': 262,
#  'true': 263,
#  'seem': 264,
#  'pretty': 265,
#  'ultimately': 266,
#  'part': 267,
#  'tv': 268,
#  'care': 269,
#  'think': 270,
#  'want': 271,
#  'sweet': 272,
#  'dark': 273,
#  'together': 274,
#  'away': 275,
#  'theater': 276,
#  'laughs': 277,
#  'day': 278,
#  'works': 279,
#  'place': 280,
#  'flick': 281,
#  'anyone': 282,
#  'writer': 283,
#  'moving': 284,
#  'piece': 285,
#  'horror': 286,
#  'fans': 287,
#  'comic': 288,
#  'bit': 289,
#  'need': 290,
#  'visual': 291,
#  'effects': 292,
#  'again': 293,
#  'once': 294,
#  'sometimes': 295,
#  'feature': 296,
#  'low': 297,
#  'then': 298,
#  'silly': 299,
#  'nearly': 300,
#  'set': 301,
#  'looking': 302,
#  'narrative': 303,
#  'dull': 304,
#  'direction': 305,
#  'familiar': 306,
#  'under': 307,
#  'why': 308,
#  'fascinating': 309,
#  'genre': 310,
#  'whose': 311,
#  'she': 312,
#  'clever': 313,
#  'mind': 314,
#  'series': 315,
#  'children': 316,
#  'actually': 317,
#  'whole': 318,
#  'face': 319,
#  'hour': 320,
#  'age': 321,
#  'minute': 322,
#  'done': 323,
#  'gives': 324,
#  'past': 325,
#  'experience': 326,
#  'men': 327,
#  'power': 328,
#  'since': 329,
#  'trying': 330,
#  'charm': 331,
#  'girl': 332,
#  'modern': 333,
#  'lives': 334,
#  'always': 335,
#  'title': 336,
#  'culture': 337,
#  'interest': 338,
#  'next': 339,
#  'idea': 340,
#  'black': 341,
#  'level': 342,
#  'predictable': 343,
#  'small': 344,
#  'coming': 345,
#  'classic': 346,
#  'book': 347,
#  'school': 348,
#  'feeling': 349,
#  'matter': 350,
#  'study': 351,
#  'light': 352,
#  'simply': 353,
#  'intelligent': 354,
#  'wit': 355,
#  'amusing': 356,
#  'live': 357,
#  'mr': 358,
#  'short': 359,
#  'romance': 360,
#  'screenplay': 361,
#  'head': 362,
#  'enjoyable': 363,
#  'smart': 364,
#  'become': 365,
#  'actor': 366,
#  'easy': 367,
#  'thought': 368,
#  'instead': 369,
#  'each': 370,
#  'ideas': 371,
#  'strong': 372,
#  'summer': 373,
#  'everything': 374,
#  'play': 375,
#  'serious': 376,
#  'woman': 377,
#  'premise': 378,
#  'middle': 379,
#  'everyone': 380,
#  'fresh': 381,
#  'especially': 382,
#  'reality': 383,
#  'put': 384,
#  'despite': 385,
#  'john': 386,
#  'hours': 387,
#  'energy': 388,
#  'worst': 389,
#  'himself': 390,
#  'quirky': 391,
#  'obvious': 392,
#  'lack': 393,
#  'enjoy': 394,
#  'home': 395,
#  'engaging': 396,
#  'effort': 397,
#  'de': 398,
#  'version': 399,
#  'stuff': 400,
#  'dramatic': 401,
#  'charming': 402,
#  'suspense': 403,
#  'french': 404,
#  'filmmaker': 405,
#  'solid': 406,
#  'filmmakers': 407,
#  'now': 408,
#  'spirit': 409,
#  "'d": 410,
#  'death': 411,
#  'jokes': 412,
#  'debut': 413,
#  'written': 414,
#  'likely': 415,
#  'slow': 416,
#  'recent': 417,
#  'message': 418,
#  'filmmaking': 419,
#  'adventure': 420,
#  'shot': 421,
#  'camera': 422,
#  'perfect': 423,
#  'powerful': 424,
#  'stories': 425,
#  'role': 426,
#  'sort': 427,
#  'political': 428,
#  'laugh': 429,
#  'leave': 430,
#  'else': 431,
#  'beautiful': 432,
#  'fine': 433,
#  'ending': 434,
#  'either': 435,
#  'different': 436,
#  'tone': 437,
#  'truly': 438,
#  'directed': 439,
#  'opera': 440,
#  'line': 441,
#  'melodrama': 442,
#  'goes': 443,
#  'side': 444,
#  'probably': 445,
#  'portrait': 446,
#  'production': 447,
#  'manages': 448,
#  'scene': 449,
#  'stand': 450,
#  'viewers': 451,
#  'project': 452,
#  'heavy': 453,
#  'class': 454,
#  'turns': 455,
#  'reason': 456,
#  'sex': 457,
#  'along': 458,
#  'believe': 459,
#  'crime': 460,
#  'beyond': 461,
#  'dead': 462,
#  'audiences': 463,
#  'surprisingly': 464,
#  'wo': 465,
#  'dumb': 466,
#  'run': 467,
#  'becomes': 468,
#  'rare': 469,
#  'turn': 470,
#  'offers': 471,
#  'social': 472,
#  'passion': 473,
#  'boring': 474,
#  'boy': 475,
#  'second': 476,
#  'simple': 477,
#  'impossible': 478,
#  'talent': 479,
#  'sure': 480,
#  'close': 481,
#  'completely': 482,
#  'novel': 483,
#  'intelligence': 484,
#  'disney': 485,
#  'intriguing': 486,
#  'left': 487,
#  'personal': 488,
#  'game': 489,
#  'deeply': 490,
#  'sad': 491,
#  'exercise': 492,
#  'ends': 493,
#  'ride': 494,
#  'above': 495,
#  'act': 496,
#  'budget': 497,
#  'eye': 498,
#  'complex': 499,
#  'acted': 500,
#  'tell': 501,
#  'pleasure': 502,
#  'moral': 503,
#  'ways': 504,
#  'satisfying': 505,
#  'eyes': 506,
#  'spy': 507,
#  'b': 508,
#  'pop': 509,
#  'writing': 510,
#  'cool': 511,
#  'tragedy': 512,
#  'michael': 513,
#  'mystery': 514,
#  'fact': 515,
#  'formula': 516,
#  'honest': 517,
#  'teen': 518,
#  'difficult': 519,
#  'gags': 520,
#  'possible': 521,
#  'themselves': 522,
#  'important': 523,
#  'hero': 524,
#  'nature': 525,
#  'easily': 526,
#  'wrong': 527,
#  'mostly': 528,
#  'already': 529,
#  'comedies': 530,
#  'creepy': 531,
#  'having': 532,
#  'flat': 533,
#  'shows': 534,
#  'form': 535,
#  'violence': 536,
#  'images': 537,
#  'rock': 538,
#  'top': 539,
#  'days': 540,
#  'concept': 541,
#  'career': 542,
#  'four': 543,
#  'mess': 544,
#  'particularly': 545,
#  'insight': 546,
#  'thin': 547,
#  'whether': 548,
#  'touching': 549,
#  'hit': 550,
#  'cold': 551,
#  'storytelling': 552,
#  'otherwise': 553,
#  'viewer': 554,
#  'future': 555,
#  'seeing': 556,
#  'looks': 557,
#  'rich': 558,
#  'plays': 559,
#  'hilarious': 560,
#  'attempt': 561,
#  'imagination': 562,
#  'single': 563,
#  'night': 564,
#  'final': 565,
#  'exactly': 566,
#  'oscar': 567,
#  'running': 568,
#  'cliches': 569,
#  'truth': 570,
#  'gentle': 571,
#  'fantasy': 572,
#  'against': 573,
#  'deep': 574,
#  'visually': 575,
#  'white': 576,
#  'working': 577,
#  "'m": 578,
#  'animation': 579,
#  'house': 580,
#  'tries': 581,
#  'attention': 582,
#  'memorable': 583,
#  'help': 584,
#  'must': 585,
#  'straight': 586,
#  'beauty': 587,
#  'city': 588,
#  'beautifully': 589,
#  'getting': 590,
#  'psychological': 591,
#  'occasionally': 592,
#  'elements': 593,
#  'guys': 594,
#  'taste': 595,
#  'terrific': 596,
#  'hand': 597,
#  'inside': 598,
#  'several': 599,
#  'worthy': 600,
#  'period': 601,
#  'adults': 602,
#  'soap': 603,
#  'approach': 604,
#  'lead': 605,
#  'fi': 606,
#  'gone': 607,
#  'doing': 608,
#  'lacks': 609,
#  'cultural': 610,
#  'usual': 611,
#  'given': 612,
#  'sequel': 613,
#  'during': 614,
#  'pictures': 615,
#  'got': 616,
#  'none': 617,
#  'sci': 618,
#  'quality': 619,
#  'found': 620,
#  'certainly': 621,
#  'strange': 622,
#  'emotionally': 623,
#  'decent': 624,
#  'nor': 625,
#  'journey': 626,
#  'parents': 627,
#  'historical': 628,
#  'free': 629,
#  'pretentious': 630,
#  'moment': 631,
#  'america': 632,
#  'change': 633,
#  'cheap': 634,
#  'epic': 635,
#  'neither': 636,
#  'fire': 637,
#  'cute': 638,
#  'cut': 639,
#  'case': 640,
#  'view': 641,
#  'fairly': 642,
#  'depth': 643,
#  'vision': 644,
#  'open': 645,
#  'told': 646,
#  'issues': 647,
#  'dog': 648,
#  'behind': 649,
#  'lost': 650,
#  'sit': 651,
#  'bring': 652,
#  'air': 653,
#  'entire': 654,
#  'fails': 655,
#  'artist': 656,
#  'guy': 657,
#  '2': 658,
#  'genuine': 659,
#  'mood': 660,
#  'expect': 661,
#  'events': 662,
#  'sequences': 663,
#  'earnest': 664,
#  'brilliant': 665,
#  'road': 666,
#  'ones': 667,
#  'clear': 668,
#  'contrived': 669,
#  'contemporary': 670,
#  'monster': 671,
#  'soul': 672,
#  'relationship': 673,
#  'major': 674,
#  'taking': 675,
#  'knows': 676,
#  'mean': 677,
#  'others': 678,
#  'hip': 679,
#  'scary': 680,
#  'previous': 681,
#  'emotions': 682,
#  'pace': 683,
#  'job': 684,
#  'loud': 685,
#  'winning': 686,
#  'entirely': 687,
#  'delivers': 688,
#  'water': 689,
#  'college': 690,
#  'remains': 691,
#  'tragic': 692,
#  'warm': 693,
#  'gorgeous': 694,
#  'joke': 695,
#  'ago': 696,
#  'crowd': 697,
#  'problem': 698,
#  'barely': 699,
#  'wonderful': 700,
#  'sexual': 701,
#  'nice': 702,
#  'kid': 703,
#  'creative': 704,
#  'meaning': 705,
#  'ugly': 706,
#  'appeal': 707,
#  'fully': 708,
#  'fast': 709,
#  '90': 710,
#  'satire': 711,
#  'thinking': 712,
#  'memory': 713,
#  'stars': 714,
#  'deal': 715,
#  'call': 716,
#  'adaptation': 717,
#  'surprising': 718,
#  'try': 719,
#  'keeps': 720,
#  'playing': 721,
#  'worse': 722,
#  'sentimental': 723,
#  'perfectly': 724,
#  'latest': 725,
#  'co': 726,
#  'living': 727,
#  'points': 728,
#  'bland': 729,
#  'television': 730,
#  'animated': 731,
#  'century': 732,
#  'needs': 733,
#  'talented': 734,
#  'excellent': 735,
#  'remarkable': 736,
#  'uses': 737,
#  'large': 738,
#  'appealing': 739,
#  'welcome': 740,
#  'somewhat': 741,
#  'hope': 742,
#  'urban': 743,
#  'impact': 744,
#  'david': 745,
#  'tension': 746,
#  '10': 747,
#  'among': 748,
#  'plenty': 749,
#  'trip': 750,
#  'car': 751,
#  'tired': 752,
#  'remake': 753,
#  'situation': 754,
#  'supposed': 755,
#  'fashioned': 756,
#  'start': 757,
#  'room': 758,
#  'thoughtful': 759,
#  'flicks': 760,
#  'ambitious': 761,
#  'sound': 762,
#  'magic': 763,
#  'robert': 764,
#  'york': 765,
#  'sustain': 766,
#  'today': 767,
#  'potential': 768,
#  'bond': 769,
#  'able': 770,
#  'wild': 771,
#  'length': 772,
#  'female': 773,
#  'proves': 774,
#  'ii': 775,
#  'giving': 776,
#  'date': 777,
#  'target': 778,
#  'stupid': 779,
#  'certain': 780,
#  'couple': 781,
#  'company': 782,
#  'force': 783,
#  'country': 784,
#  'gross': 785,
#  'offer': 786,
#  'british': 787,
#  'ya': 788,
#  'cartoon': 789,
#  'finally': 790,
#  'utterly': 791,
#  'process': 792,
#  'someone': 793,
#  'skin': 794,
#  'create': 795,
#  'lots': 796,
#  'called': 797,
#  'relationships': 798,
#  'used': 799,
#  'business': 800,
#  'brain': 801,
#  'wonder': 802,
#  'girls': 803,
#  'boys': 804,
#  'leaves': 805,
#  'surprise': 806,
#  'hell': 807,
#  'inventive': 808,
#  'let': 809,
#  'convincing': 810,
#  'use': 811,
#  'touch': 812,
#  'based': 813,
#  'non': 814,
#  'hold': 815,
#  'post': 816,
#  'dry': 817,
#  'name': 818,
#  'actress': 819,
#  'sentimentality': 820,
#  'bizarre': 821,
#  'average': 822,
#  'conflict': 823,
#  'era': 824,
#  'unsettling': 825,
#  'yourself': 826,
#  'sharp': 827,
#  'miss': 828,
#  'felt': 829,
#  'throughout': 830,
#  'odd': 831,
#  's': 832,
#  'falls': 833,
#  'grace': 834,
#  'episode': 835,
#  'impressive': 836,
#  'slightly': 837,
#  'formulaic': 838,
#  'across': 839,
#  'themes': 840,
#  'substance': 841,
#  'money': 842,
#  'happy': 843,
#  'sports': 844,
#  'wife': 845,
#  'awful': 846,
#  'unexpected': 847,
#  'alone': 848,
#  'read': 849,
#  'add': 850,
#  'edge': 851,
#  'thoroughly': 852,
#  'quiet': 853,
#  'success': 854,
#  'examination': 855,
#  'starts': 856,
#  'imagine': 857,
#  'loss': 858,
#  'ensemble': 859,
#  'paced': 860,
#  'george': 861,
#  'merely': 862,
#  'surprises': 863,
#  'indie': 864,
#  'gay': 865,
#  'highly': 866,
#  'person': 867,
#  'effective': 868,
#  'pure': 869,
#  'core': 870,
#  'manner': 871,
#  'subtle': 872,
#  'lovely': 873,
#  'engrossing': 874,
#  'until': 875,
#  'numbers': 876,
#  'perhaps': 877,
#  'politics': 878,
#  'inspired': 879,
#  'five': 880,
#  'involved': 881,
#  'soundtrack': 882,
#  'chemistry': 883,
#  'understand': 884,
#  'wanted': 885,
#  'ultimate': 886,
#  'exciting': 887,
#  'interested': 888,
#  'waste': 889,
#  'break': 890,
#  'witty': 891,
#  'hot': 892,
#  'wants': 893,
#  'crazy': 894,
#  'pay': 895,
#  'mildly': 896,
#  'questions': 897,
#  'brothers': 898,
#  'share': 899,
#  'provocative': 900,
#  'spiritual': 901,
#  'although': 902,
#  'mediocre': 903,
#  'overall': 904,
#  'casting': 905,
#  'master': 906,
#  'flaws': 907,
#  'ill': 908,
#  'mother': 909,
#  'words': 910,
#  'battle': 911,
#  'generation': 912,
#  'considerable': 913,
#  'flawed': 914,
#  'maybe': 915,
#  'promise': 916,
#  'third': 917,
#  'dream': 918,
#  'party': 919,
#  'voice': 920,
#  'frame': 921,
#  'typical': 922,
#  'franchise': 923,
#  'begins': 924,
#  'stylish': 925,
#  'taken': 926,
#  'trouble': 927,
#  'slapstick': 928,
#  'seat': 929,
#  'filled': 930,
#  'murder': 931,
#  'drag': 932,
#  'sophisticated': 933,
#  'unique': 934,
#  'child': 935,
#  'plain': 936,
#  'unfunny': 937,
#  'colorful': 938,
#  'sincere': 939,
#  'key': 940,
#  'saw': 941,
#  'twists': 942,
#  'badly': 943,
#  'painful': 944,
#  'extreme': 945,
#  'equally': 946,
#  'fiction': 947,
#  'poor': 948,
#  'question': 949,
#  'giant': 950,
#  'believable': 951,
#  'ability': 952,
#  'problems': 953,
#  'evil': 954,
#  'humanity': 955,
#  'red': 956,
#  'tedious': 957,
#  'ages': 958,
#  'warmth': 959,
#  'central': 960,
#  'sensitive': 961,
#  'bright': 962,
#  'indulgent': 963,
#  'execution': 964,
#  'spielberg': 965,
#  'handed': 966,
#  'successful': 967,
#  'intimate': 968,
#  'friendship': 969,
#  'blood': 970,
#  'course': 971,
#  'screenwriter': 972,
#  'guilty': 973,
#  'niro': 974,
#  'attempts': 975,
#  'williams': 976,
#  'steven': 977,
#  'natural': 978,
#  'public': 979,
#  'forced': 980,
#  'terrible': 981,
#  'situations': 982,
#  'green': 983,
#  'brings': 984,
#  'goofy': 985,
#  'shoot': 986,
#  'recommend': 987,
#  'mark': 988,
#  'society': 989,
#  'masterpiece': 990,
#  'standard': 991,
#  'artistic': 992,
#  'produced': 993,
#  'terms': 994,
#  'computer': 995,
#  'list': 996,
#  'mix': 997,
#  'grief': 998,
#  'talk': 999,
#  'places': 1000,
#  ...}

# %%
embeddings_index.get("world")
# Out:
# array([ 0.0754,  0.0087,  0.0769, -0.3932, -0.0417, -0.108 , -0.3165,
#         0.1129,  0.403 , -0.0546, -0.0775,  0.1394, -0.3437,  0.0056,
#        -0.2149, -0.0792,  0.1391,  0.2636, -0.0282,  0.1147,  0.1472,
#        -0.1183, -0.1531, -0.1508,  0.017 ,  0.1189, -0.0835,  0.0755,
#         0.2867, -0.4668,  0.2741, -0.0912, -0.1706, -0.2259,  0.0597,
#        -0.0526, -0.077 , -0.0305, -0.2019,  0.2152, -0.019 , -0.2326,
#        -0.0863, -0.0484, -0.1292, -0.0007,  0.1289,  0.2168,  0.2151,
#         0.0812,  0.1065, -0.0938,  0.425 , -0.0092,  0.1133,  0.0941,
#        -0.0996,  0.0506,  0.0734, -0.0613,  0.1535, -0.1017,  0.0306,
#         0.0815, -0.0224,  0.0576,  0.0482, -0.1198, -0.3098,  0.2956,
#        -0.1275,  0.1479,  0.2167,  0.054 ,  0.0729, -0.154 , -0.2815,
#        -0.1891, -0.1874,  0.2209,  0.2044,  0.0526, -0.1605, -0.0271,
#         0.1313, -0.0396,  0.0286,  0.0649,  0.0636,  0.0853,  0.0248,
#         0.3101, -0.0535, -0.0268, -0.0407, -0.2798,  0.1898, -0.0054,
#        -0.0443,  0.1353,  0.0199,  0.1634,  0.3282,  0.0197, -0.0673,
#        -0.0806, -0.0367, -0.0786, -0.1549,  0.0105,  0.1865, -0.2218,
#         0.2288,  0.2267, -0.5789, -0.1183, -0.2457, -0.1934,  0.2295,
#        -0.0397, -0.0014,  0.1186, -0.1883, -0.082 ,  0.0471, -0.2013,
#         0.1864,  0.1529, -0.0378,  0.1303, -0.1471,  0.0485,  0.1145,
#        -0.0967,  0.3181, -0.0302,  0.0984, -0.1302,  0.0921, -0.1183,
#         0.3433, -0.1972, -0.3087,  0.4075,  0.0538, -0.0207, -0.1252,
#        -0.152 , -0.007 ,  0.3078,  0.0054, -0.0146,  0.1429,  0.2244,
#        -0.0248,  0.157 ,  0.0607, -0.1681, -0.0903, -0.0717,  0.6643,
#        -0.3325, -0.1082, -0.1551,  0.1493, -0.0832,  0.3486,  0.0511,
#         0.3011, -0.1872,  0.0316,  0.0406,  0.3518, -0.0046, -0.0895,
#        -0.0938,  0.1798, -0.3167,  0.0066,  0.0183,  0.2773,  0.0316,
#         0.0024, -0.0971, -0.0096, -0.0502, -0.0465,  0.5095,  0.23  ,
#        -0.0515,  0.1055,  0.1004, -0.2089,  0.0476,  0.0588, -0.1186,
#         0.083 ,  0.0548,  0.0432, -0.0848, -0.162 , -0.1719,  0.1297,
#         0.1554, -0.1211, -0.0495, -0.2012, -0.2606,  0.209 , -0.4714,
#        -0.0746,  0.4734, -0.1043, -0.1725,  0.0179, -0.4714, -0.0557,
#        -0.1569,  0.1859,  0.041 , -0.1243,  0.2856, -0.0205, -0.1556,
#         0.2376, -0.01  , -0.05  ,  0.0704, -0.1302,  0.2683,  0.1592,
#        -0.0452,  0.3183,  0.0421, -0.0727, -0.2507,  0.0395, -0.0186,
#        -0.0821, -0.0623, -0.135 , -0.1099,  0.083 ,  0.0229, -0.317 ,
#        -0.1958,  0.0111, -0.0666, -0.0226, -0.0663, -0.3262,  0.1479,
#         0.0868,  0.3328,  0.1187, -0.1491, -0.149 , -0.0417,  0.0972,
#        -0.0982,  0.1927,  0.0105,  0.0012,  0.0603,  0.2414,  0.2071,
#        -0.0407, -0.1532,  0.0366, -0.025 , -0.08  , -0.107 ,  0.0999,
#         0.1299, -0.1693, -0.0348, -0.0294,  0.0384, -0.4734, -0.1009,
#         0.1186, -0.1781, -0.1647, -0.2362,  0.0132,  0.0833, -0.0429,
#         0.0269, -0.2338, -0.039 , -0.0168, -0.0681, -0.1647,  0.053 ,
#         0.0446,  0.1213, -0.0236, -0.1167,  0.0294, -0.2431],
#       dtype=float32)

# %%
#make the embedding matrix for all our words 
vocab_size = min(max_features, len(tokenizer.word_index))
embedding_matrix = np.zeros((vocab_size + 1, embed_size))
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i,:] = embedding_vector

# %%
embedding_matrix.shape
# Out:
# (17781, 300)

# %%
#make the y variable one hot encoded
from keras.utils import to_categorical
y_ohe = to_categorical(y, num_classes=len(y.unique()))

# %%
#build a model
def build_model1(lr=0.0, lr_d=0.0, units=0, spatial_dr=0.0, kernel_size1=3, kernel_size2=2, dense_units=128, dr=0.1, conv_size=32):
    
    file_path = "best_model.hdf5"
    check_point = ModelCheckpoint(file_path, monitor = "val_loss", verbose = 1,
                                  save_best_only = True, mode = "min")
    early_stop = EarlyStopping(monitor = "val_loss", mode = "min", patience = 3)
    
    inp = Input(shape = (max_len,))
    x = Embedding(len(tokenizer.word_index) + 1, embed_size, weights = [embedding_matrix], trainable = False)(inp)
    #this is a special kind of dropout that drops or keeps each row or column together depending on if you are dropping
    #rows or columns
    x1 = SpatialDropout1D(spatial_dr)(x)

    x_gru = Bidirectional(GRU(units, return_sequences = True))(x1)
    
    #Conv1D generally works well on text data
    """
    Conv1D takes care of neighboring words. A filter length of 5 would imply a context window of 5 words, 
    i.e, the word embeddings of 5 words, not 5 elements within a single embedding. 
    Images have height and width, so we use conv2d, sentences are linear lists of words, so conv1d. 
    The "2d" or "3d" specifies how we loop through the matrix; its not the rank of the convolution kernel itself.
    """
    x1 = Conv1D(conv_size, kernel_size=kernel_size1, padding='valid', kernel_initializer='he_uniform')(x_gru)
    avg_pool1_gru = GlobalAveragePooling1D()(x1)
    max_pool1_gru = GlobalMaxPooling1D()(x1)
    
    x3 = Conv1D(conv_size, kernel_size=kernel_size2, padding='valid', kernel_initializer='he_uniform')(x_gru)
    avg_pool3_gru = GlobalAveragePooling1D()(x3)
    max_pool3_gru = GlobalMaxPooling1D()(x3)
    
    
    
    x_lstm = Bidirectional(LSTM(units, return_sequences = True))(x1)
    
    x1 = Conv1D(conv_size, kernel_size=kernel_size1, padding='valid', kernel_initializer='he_uniform')(x_lstm)
    avg_pool1_lstm = GlobalAveragePooling1D()(x1)
    max_pool1_lstm = GlobalMaxPooling1D()(x1)
    
    x3 = Conv1D(conv_size, kernel_size=kernel_size2, padding='valid', kernel_initializer='he_uniform')(x_lstm)
    avg_pool3_lstm = GlobalAveragePooling1D()(x3)
    max_pool3_lstm = GlobalMaxPooling1D()(x3)
    
    #Concatenates all the layers we have just made
    x = concatenate([avg_pool1_gru, max_pool1_gru, avg_pool3_gru, max_pool3_gru,
                    avg_pool1_lstm, max_pool1_lstm, avg_pool3_lstm, max_pool3_lstm])
    #Batch Normalization increases the speed for training
    #Often it is used between the linear and non-linear layers in your network because it normalizes
    #the input to your activation function but can be used anywhere you desire
    x = BatchNormalization()(x)
    x = Dropout(dr)(Dense(dense_units, activation='relu') (x))
    x = BatchNormalization()(x)
    x = Dropout(dr)(Dense(int(dense_units / 2), activation='relu') (x))
    
    #Final prediction layer
    x = Dense(5, activation = "sigmoid")(x)
    
    
    model = Model(inputs = inp, outputs = x)
    model.compile(loss = "binary_crossentropy", optimizer = Adam(lr = lr, decay = lr_d), metrics = ["accuracy"])
    history = model.fit(X_train, y_ohe, batch_size = 128, epochs = 1, validation_split=0.1, 
                        verbose = 1, callbacks = [check_point, early_stop])
    model = load_model(file_path)
    return model

# %%
model1 = build_model1(lr = 1e-3, lr_d = 1e-10, units = 64, spatial_dr = 0.3, kernel_size1=3, kernel_size2=2, dense_units=32, dr=0.1, conv_size=32)
# Out:
# Train on 140454 samples, validate on 15606 samples
# Epoch 1/1
# 140454/140454 [==============================] - 450s 3ms/step - loss: 0.3525 - acc: 0.8413 - val_loss: 0.3196 - val_acc: 0.8514
#
# Epoch 00001: val_loss improved from inf to 0.31962, saving model to best_model.hdf5
